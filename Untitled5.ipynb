# %%
import corpustool.models

# %%
help(corpustool.models)
# Out:
# Help on module corpustool.models in corpustool:
#
# NAME
#     corpustool.models
#
# CLASSES
#     django.db.models.base.Model(builtins.object)
#         DepRel
#         Document
#         Lemma
#         Occurence
#         Token
#
#     class DepRel(django.db.models.base.Model)
#      |  DepRel(*args, **kwargs)
#      |
#      |  DepRel(id, head, dependant, typerel)
#      |
#      |  Method resolution order:
#      |      DepRel
#      |      django.db.models.base.Model
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  dependant_id = <django.db.models.query_utils.DeferredAttribute object>
#      |  head_id = <django.db.models.query_utils.DeferredAttribute object>
#      |  id = <django.db.models.query_utils.DeferredAttribute object>
#      |  typerel = <django.db.models.query_utils.DeferredAttribute object>
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(Document.objects.all().values())

# %%
df.dropna()
# Out:
#             date        department    id  mark sex  study_year         title
# 171   2017-03-28  Economic Science  2308  60.0   f         2.0  DPe_10_1.txt
# 172   2017-03-28  Economic Science  2309  55.0   f         2.0  DPe_10_2.txt
# 173   2017-03-28  Economic Science  2310  30.0   f         2.0  DPe_11_2.txt
# 174   2017-03-28  Economic Science  2311  60.0   f         2.0  DPe_12_1.txt
# 175   2017-03-28  Economic Science  2312  60.0   f         2.0  DPe_12_2.txt
# 176   2017-03-28  Economic Science  2313  55.0   m         2.0  DPe_13_1.txt
# 177   2017-03-28  Economic Science  2314  65.0   m         2.0  DPe_13_2.txt
# 178   2017-03-28  Economic Science  2315  60.0   f         2.0  DPe_14_1.txt
# 179   2017-03-28  Economic Science  2316  60.0   f         2.0  DPe_14_2.txt
# 180   2017-03-28  Economic Science  2317  60.0   f         2.0  DPe_15_1.txt
# 181   2017-03-28  Economic Science  2318  60.0   f         2.0  DPe_15_2.txt
# ...

# %%
df1 = pd.DataFrame(Lemma.objects.all().values())

# %%
df1.dropna().head()
# Out:
#       id   pos    text
# 0  31111  PRON  -pron-
# 1  31112  VERB      be
# 2  31113   ADV  widely
# 3  31114  VERB    know
# 4  31115   ADP    that

# %%
df2 = pd.DataFrame(Token.objects.all().values())

# %%
df2.head()
# Out:
#   grammar     id  lemma_id    text
# 0    None  36867     31111      it
# 1    None  36868     31112      is
# 2    None  36869     31113  widely
# 3    None  36870     31114   known
# 4    None  36871     31115    that

# %%
df3 = pd.DataFrame(Occurence.objects.all().values())

# %%
df3.head()
# Out:
#    document_id      id  index sentence  space_after  token_id
# 0         2137  647842      0     None         True     36867
# 1         2137  647843      1     None         True     36868
# 2         2137  647844      2     None         True     36869
# 3         2137  647845      3     None         True     36870
# 4         2137  647846      4     None         True     36871
